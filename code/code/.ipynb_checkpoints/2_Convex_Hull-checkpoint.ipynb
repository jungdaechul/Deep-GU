# %%
from batchgenerators.utilities.file_and_folder_operations import *
import shutil

# %%
#vol_base='/home/ldh/1_Tindex/data/T_Index_nii_test/volume/'
vol_base='/home/ldh/1_Tindex/data/T_Index_nii_final_test/volume/'
for v in subfiles(vol_base):
    file_name=v.split('/')[-1].split('0000')[0][:-1]
    print(file_name)
    
    mask_path=v.replace('volume','mask').replace('_0000','')
    pred_path=v.replace('volume','prediction_4').replace('_0000','')
    
    mask_base=vol_base.replace('volume','T_Index_extract_mask')+'/'+file_name
    maybe_mkdir_p(mask_base)
    
    pred_base=vol_base.replace('volume','T_Index_extract_pred_4')+'/'+file_name
    maybe_mkdir_p(pred_base)
    
    shutil.copy(v, mask_base+'/imaging.nii.gz')
    shutil.copy(mask_path, mask_base+'/segmentation.nii.gz')
    
    shutil.copy(v, pred_base+'/imaging.nii.gz')
    shutil.copy(pred_path, pred_base+'/segmentation.nii.gz')
# Out:
# 001_2627046_211022_CMP_preop_KO
# 001_2627046_211022_NP_preop_HK
# 002_3685594_211022_CMP_preop_KO
# 002_3685594_211022_NP_preop_HK
# 002_3685594_220325_CMP_KO
# 002_3685594_220325_NP_HK
# 003_2597321_211217_CMP_preop_KO
# 003_2597321_211217_NP_preop_HK
# 004_10506248_211220_CMP_preop_KO
# 004_10506248_211220_NP_preop_HK
# 004_10506248_220603_CMP_KO
# 004_10506248_220603_NP_HK
# 004_10506248_221202_CMP_KO
# 004_10506248_221202_NP_KO
# 005_5681816_211223_CMP_preop_KO
# 005_5681816_211223_NP_preop_HK
# 006_10515548_220103_CMP_preop_KO
# 006_10515548_220103_NP_preop_HK
# 006_10515548_220607_CMP_KO
# 006_10515548_220607_NP_HK
# 007_8572841_220127_CMP_preop_KO
# 007_8572841_220127_NP_preop_HK
# 009_10537082_220215_CMP_preop_KO
# 009_10537082_220215_NP_preop_HK
# 010_10537082_220311_CMP_preop_KO
# 010_10554561_220311_NP_preop_HK
# 011_8317556_220509_CMP_preop_KO
# 011_8317556_220509_NP_preop_HK
# 012_10652021_20220812_NP_preop_HK
# 012_10652021_220812_CMP_preop_KO

# %%
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np
from scipy.spatial import ConvexHull
from scipy.ndimage import binary_erosion
from skimage.measure import label
from skimage.morphology import convex_hull_image
from batchgenerators.utilities.file_and_folder_operations import *
import os

# %%
def sinus_seg(seg1, seg2, seg_ori_data):
    seg_dataset = []
    for seg_kid in [seg1,seg2]:
        x,y,z = np.where(seg_kid==1)
        
        x_min = max(min(x)-5,0)
        y_min = max(min(y)-5,0)
        z_min = max(min(z)-5,0)
        
        x_max = min(max(x)+5, seg_kid.shape[0])
        y_max = min(max(y)+5, seg_kid.shape[1])
        z_max = min(max(z)+5, seg_kid.shape[2])                                   
        
        seg_kid_crop = seg_kid[x_min:x_max, y_min:y_max, z_min:z_max]
        crop_result = convex_hull_image(seg_kid_crop.astype('uint8'))
        
        result = np.zeros(seg_kid.shape)
        result[x_min:x_max, y_min:y_max, z_min:z_max] = crop_result
        
        seg_result = binary_erosion(result,iterations=3)
        values = [0,4]
        seg_result *= np.isin(seg_ori_data, values)
        seg_result = getLargestCC(seg_result)
        seg_dataset.append(seg_result)
        
    seg_new_data = np.zeros(seg_kid.shape)
    seg_new_data[seg_dataset[0]==1] = 1
    seg_new_data[seg_dataset[1]==1] = 1
    
    return seg_new_data

# %%
def getLargestCC(segmentation):
    labels = label(segmentation)
    if labels.max() ==0:
        return 0
    else:
        #assert( labels.max() != 0 ) # assume at least 1 CC
        largestCC = labels == np.argmax(np.bincount(labels.flat)[1:])+1
        return largestCC

# %%
def sinus_seg_main(seg_path, save_path):
    if not isfile(save_path):
        # 1. data load 
        seg = nib.load(seg_path)
        seg_data = seg.get_fdata()
        seg_ori_data = seg_data.copy()
        seg_data[seg_data!=1]=0

        # 2. seg1, seg2 : left, right kidney
        labels = label(seg_data)
        #assert len(np.unique(labels))==3
        region_list=[]
        for b in range(1,len(np.unique(labels))):
            isl = labels==b
            region = len(np.where(isl==True)[0])
            region_list.append(region)
        region_list_sort = np.argsort(region_list)

        seg1 = labels==region_list_sort[-1]+1
        seg2 = labels==region_list_sort[-2]+1

        # 3. sinus seg
        result = sinus_seg(seg1, seg2, seg_ori_data)
        seg_ori_data[result==1]=4
        seg_ori_data[seg_ori_data==1]=0
        seg_ori_data[seg1==1]=1
        seg_ori_data[seg2==1]=1

        vol = nib.Nifti1Image(seg_ori_data,seg.affine)
        nib.save(vol, save_path)
    else:
        pass
    
    print(save_path)

# %%
data_path = '/home/ldh/1_Tindex/data/T_Index_nii'
folders = subfolders(data_path, join=False)
seg_path=[]
save_path=[]
for fold in folders:
    seg_path.append(data_path+'/'+fold+'/segmentation.nii.gz')
    save_path.append(data_path+'/'+fold+'/segmentation_sinus.nii.gz')

# %%
from multiprocessing import Pool
p = Pool(8)
p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
p.close()
p.join()
# Out:
# /home/ldh/1_Tindex/data/T_Index_nii/001/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/033/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/023/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/010/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/061/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/041/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/055/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/069/segmentation_sinus.nii.gz
#
#
#
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/003/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/035/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/026/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/044/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/063/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/016/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/070/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/057/segmentation_sinus.nii.gz
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/037/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/048/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/005/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/029/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/072/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/064/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/058/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/018/segmentation_sinus.nii.gz
#
#
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/053/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/040/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/073/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/008/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/032/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/067/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/060/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/021/segmentation_sinus.nii.gz
#
#
#
#
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/086/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/080/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/074/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/092/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/102/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/107/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/126/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/113/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/081/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/075/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/087/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/103/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/095/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/108/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/127/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/116/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/082/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/088/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/104/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/076/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/098/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/109/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/128/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/083/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/119/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/105/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/090/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/100/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/112/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/129/segmentation_sinus.nii.gz
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/131/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/120/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/142/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/077/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/160/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/171/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/150/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/135/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/182/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/196/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/143/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/172/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/162/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/152/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/200/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/137/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/183/segmentation_sinus.nii.gz
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/175/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/197/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/164/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/144/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/203/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/153/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/140/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/186/segmentation_sinus.nii.gz
#
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/179/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/146/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/198/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/158/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/212/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/195/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/167/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/205/segmentation_sinus.nii.gz
#
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/199/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/220/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/248/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/254/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/237/segmentation_sinus.nii.gz
#
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/225/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/250/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/241/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/230/segmentation_sinus.nii.gz
#
#
# /home/ldh/1_Tindex/data/T_Index_nii/251/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/232/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/216/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/242/segmentation_sinus.nii.gz/home/ldh/1_Tindex/data/T_Index_nii/253/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/208/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/217/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/246/segmentation_sinus.nii.gz
#
# /home/ldh/1_Tindex/data/T_Index_nii/218/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/258/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/269/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/276/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/308/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/295/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/274/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/299/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/301/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/305/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/281/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/282/segmentation_sinus.nii.gz
# /home/ldh/1_Tindex/data/T_Index_nii/293/segmentation_sinus.nii.gz

# %% [markdown]
# # Test

# %%
def sinus_seg_main(seg_path, save_path):
    try:
        # 1. data load 
        seg = nib.load(seg_path)
        seg_data = seg.get_fdata()
        seg_ori_data = seg_data.copy()
        seg_data[seg_data!=1]=0

        # 2. seg1, seg2 : left, right kidney
        labels = label(seg_data)
        #assert len(np.unique(labels))==3
        region_list=[]
        for b in range(1,len(np.unique(labels))):
            isl = labels==b
            region = len(np.where(isl==True)[0])
            region_list.append(region)
        region_list_sort = np.argsort(region_list)

        seg1 = labels==region_list_sort[-1]+1
        seg2 = labels==region_list_sort[-2]+1

        # 3. sinus seg
        result = sinus_seg(seg1, seg2, seg_ori_data)
        seg_ori_data[result==1]=4
        seg_ori_data[seg_ori_data==1]=0
        seg_ori_data[seg1==1]=1
        seg_ori_data[seg2==1]=1

        vol = nib.Nifti1Image(seg_ori_data,seg.affine)
        nib.save(vol, save_path)
    except:
        print(save_path)

# %%
#data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0'
folders = subfolders(data_path, join=False)
seg_path=[]
save_path=[]
for fold in folders:
    seg_path.append(data_path+'/'+fold+'/segmentation.nii.gz')
    save_path.append(data_path+'/'+fold+'/segmentation_sinus.nii.gz')

# %%
from multiprocessing import Pool
p = Pool(8)
p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
p.close()
p.join()
# Out:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-57:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-cdb033b6677c> in <module>
#       3 p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
#       4 p.close()
# ----> 5 p.join()
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in join(self)
#     554         elif self._state not in (CLOSE, TERMINATE):
#     555             raise ValueError("In unknown state")
# --> 556         self._worker_handler.join()
#     557         self._task_handler.join()
#     558         self._result_handler.join()
#
# ~/anaconda3/envs/uk/lib/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# ~/anaconda3/envs/uk/lib/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
#data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1'
folders = subfolders(data_path, join=False)
seg_path=[]
save_path=[]
for fold in folders:
    seg_path.append(data_path+'/'+fold+'/segmentation.nii.gz')
    save_path.append(data_path+'/'+fold+'/segmentation_sinus.nii.gz')
from multiprocessing import Pool
p = Pool(8)
p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
p.close()
p.join()

# %%
#data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2'
folders = subfolders(data_path, join=False)
seg_path=[]
save_path=[]
for fold in folders:
    seg_path.append(data_path+'/'+fold+'/segmentation.nii.gz')
    save_path.append(data_path+'/'+fold+'/segmentation_sinus.nii.gz')
from multiprocessing import Pool
p = Pool(8)
p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
p.close()
p.join()

# %%
#data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3'
folders = subfolders(data_path, join=False)
seg_path=[]
save_path=[]
for fold in folders:
    seg_path.append(data_path+'/'+fold+'/segmentation.nii.gz')
    save_path.append(data_path+'/'+fold+'/segmentation_sinus.nii.gz')
from multiprocessing import Pool
p = Pool(8)
p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
p.close()
p.join()

# %%
#data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4'
folders = subfolders(data_path, join=False)
seg_path=[]
save_path=[]
for fold in folders:
    seg_path.append(data_path+'/'+fold+'/segmentation.nii.gz')
    save_path.append(data_path+'/'+fold+'/segmentation_sinus.nii.gz')
from multiprocessing import Pool
p = Pool(8)
p.starmap_async(sinus_seg_main, zip(seg_path,save_path))
p.close()
p.join()
