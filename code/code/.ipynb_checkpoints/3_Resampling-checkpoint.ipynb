# %%
from batchgenerators.utilities.file_and_folder_operations import *
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import resize
from scipy.ndimage.interpolation import map_coordinates
from batchgenerators.augmentations.utils import resize_segmentation
from collections import OrderedDict

# %%
def resample_tindex(fold):
    
    vol_path = data_path+'/'+fold+'/imaging.nii.gz'
    seg_path = data_path+'/'+fold+'/segmentation_sinus.nii.gz'
    new_vol_path = data_path+'/'+fold+'/imaging_r.nii.gz'
    new_seg_path = data_path+'/'+fold+'/segmentation_sinus_r.nii.gz'
    
    if (not isfile(new_vol_path)) & (not isfile(new_seg_path)):
        a = nib.load(vol_path)
        vol = a.get_fdata()

        b = nib.load(seg_path)
        seg = b.get_fdata()

        aff = b.affine
        ori_x = abs(aff[0][0])
        ori_z = aff[2][2]
        ori_spacing = np.array([ori_x, ori_x, ori_z])
        new_spacing = np.array([ori_x, ori_x, ori_x])

        new_affine = aff.copy()
        new_affine[2][2] = ori_x

        vol = np.expand_dims(vol,axis=0)
        seg = np.expand_dims(seg,axis=0)
        vol_r, seg_r = resample_patient(vol, seg, ori_spacing, new_spacing, order_data=3, order_seg=1,
                                     force_separate_z=None, order_z_data=0, order_z_seg=0,
                                     separate_z_anisotropy_threshold=3)
        vol_r = np.squeeze(vol_r)
        seg_r = np.squeeze(seg_r)

        nifti = nib.Nifti1Image(vol_r, new_affine)
        nib.save(nifti, new_vol_path)
        nifti = nib.Nifti1Image(seg_r, new_affine)
        nib.save(nifti, new_seg_path)
        
    else:
        pass
    
    print('save complete: ', new_vol_path)
    print('save complete: ', new_seg_path)

# %%
def get_do_separate_z(spacing, anisotropy_threshold=3): # 3
    do_separate_z = (np.max(spacing) / np.min(spacing)) > anisotropy_threshold
    return do_separate_z
def get_lowres_axis(new_spacing):
    # 가장 높은 spacing값의 축(low resolution)
    axis = np.where(max(new_spacing) / np.array(new_spacing) == 1)[0]  # find which axis is anisotropic
    return axis

def resample_patient(data, seg, original_spacing, target_spacing, order_data=3, order_seg=0, force_separate_z=False,
                     cval_data=0, cval_seg=-1, order_z_data=0, order_z_seg=0,
                     separate_z_anisotropy_threshold=3):

    if data is not None:
        shape = np.array(data[0].shape)
    else:
        shape = np.array(seg[0].shape)
    new_shape = np.round(((np.array(original_spacing) / np.array(target_spacing)).astype(float) * shape)).astype(int)

    if force_separate_z is not None:
        do_separate_z = force_separate_z
        if force_separate_z:
            axis = get_lowres_axis(original_spacing)
        else:
            axis = None
    else:
        if get_do_separate_z(original_spacing, separate_z_anisotropy_threshold):
            do_separate_z = True
            axis = get_lowres_axis(original_spacing)
        elif get_do_separate_z(target_spacing, separate_z_anisotropy_threshold):
            do_separate_z = True
            axis = get_lowres_axis(target_spacing)
        else:
            do_separate_z = False
            axis = None

    if axis is not None:
        if len(axis) == 3:
            axis = (0, )
        elif len(axis) == 2:
            print("WARNING: axis has len 2, axis: %s, spacing: %s, target_spacing: %s" % (str(axis), original_spacing, target_spacing))
            do_separate_z = False
        else:
            pass
        
    if data is not None:
        data_reshaped = resample_data_or_seg(data, new_shape, False, axis, order_data, do_separate_z, cval=cval_data,
                                             order_z=order_z_data)
    else:
        data_reshaped = None
    if seg is not None:
        seg_reshaped = resample_data_or_seg(seg, new_shape, True, axis, order_seg, do_separate_z, cval=cval_seg,
                                            order_z=order_z_seg)
    else:
        seg_reshaped = None
    return data_reshaped, seg_reshaped

def resample_data_or_seg(data, new_shape, is_seg, axis=None, order=3, do_separate_z=False, cval=0, order_z=0):
    assert len(data.shape) == 4, "data must be (c, x, y, z)"
    if is_seg:
        resize_fn = resize_segmentation # batchgenerators
        kwargs = OrderedDict()
    else:
        resize_fn = resize # skimage
        kwargs = {'mode': 'edge', 'anti_aliasing': False}

    dtype_data = data.dtype
    data = data.astype(float)
    shape = np.array(data[0].shape)
    new_shape = np.array(new_shape)

    if np.any(shape != new_shape):
        if do_separate_z:
            print("separate z, order in z is", order_z, "order inplane is", order)
            assert len(axis) == 1, "only one anisotropic axis supported"
            axis = axis[0]
            if axis == 0: # [1,2]
                new_shape_2d = new_shape[1:]
            elif axis == 1: # [0,2]
                new_shape_2d = new_shape[[0, 2]]
            else: # [0,1]
                new_shape_2d = new_shape[:-1]

            reshaped_final_data = []
            for c in range(data.shape[0]):
                reshaped_data = []
                for slice_id in range(shape[axis]):
                    if axis == 0:
                        reshaped_data.append(resize_fn(data[c, slice_id], new_shape_2d, order, **kwargs))
                    elif axis == 1:
                        reshaped_data.append(resize_fn(data[c, :, slice_id], new_shape_2d, order, **kwargs))
                    else:
                        reshaped_data.append(resize_fn(data[c, :, :, slice_id], new_shape_2d, order, **kwargs))
                reshaped_data = np.stack(reshaped_data, axis)

                # 나머지 한 축 resampling (resize: scipy.ndimage.interpolation.map_coordinates)
                if shape[axis] != new_shape[axis]:
                    rows, cols, dim = new_shape[0], new_shape[1], new_shape[2]
                    orig_rows, orig_cols, orig_dim = reshaped_data.shape

                    row_scale = float(orig_rows) / rows
                    col_scale = float(orig_cols) / cols
                    dim_scale = float(orig_dim) / dim

                    map_rows, map_cols, map_dims = np.mgrid[:rows, :cols, :dim]
                    map_rows = row_scale * (map_rows + 0.5) - 0.5
                    map_cols = col_scale * (map_cols + 0.5) - 0.5
                    map_dims = dim_scale * (map_dims + 0.5) - 0.5

                    coord_map = np.array([map_rows, map_cols, map_dims])
                    if not is_seg or order_z == 0:
                        reshaped_final_data.append(map_coordinates(reshaped_data, coord_map, order=order_z, 
                                                                   mode='nearest')[None])
                    else:
                        unique_labels = np.unique(reshaped_data)
                        reshaped = np.zeros(new_shape, dtype=dtype_data)

                        for i, cl in enumerate(unique_labels):
                            reshaped_multihot = np.round(
                                map_coordinates((reshaped_data == cl).astype(float), coord_map, order=order_z,
                                                mode='nearest'))
                            reshaped[reshaped_multihot > 0.5] = cl
                        reshaped_final_data.append(reshaped[None])
                else:
                    reshaped_final_data.append(reshaped_data[None])
            reshaped_final_data = np.vstack(reshaped_final_data)

        else:
            print("no separate z, order", order)
            reshaped = []
            for c in range(data.shape[0]):
                reshaped.append(resize_fn(data[c], new_shape, order,  **kwargs)[None])
            reshaped_final_data = np.vstack(reshaped)
        return reshaped_final_data.astype(dtype_data)
    else:
        print("no resampling necessary")
        return data

# %%
#data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask'
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii'
folders = subfolders(data_path, join=False)

# %%
from multiprocessing import Pool
p = Pool(3)
p.map(resample_tindex, folders)
p.close()
p.join()
# Out:
# save complete: save complete: save complete:

# %% [markdown]
# # Test

# %%
#data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
folders = subfolders(data_path, join=False)

# %%
from multiprocessing import Pool
p = Pool(3)
p.map(resample_tindex, folders)
p.close()
p.join()
# Out:
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/313_7074817_151218_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/313_7074817_151218_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/336_3828394_160818_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/336_3828394_160818_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/364_8479256_170705_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/364_8479256_170705_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/317_7665620_160217_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/317_7665620_160217_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/338_8328258_161004_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/338_8328258_161004_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/369_8495693_170724_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/369_8495693_170724_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/339_8333066_160924_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/339_8333066_160924_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/341_5514749_161111_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/341_5514749_161111_preop/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/374_7505332_170913_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/374_7505332_170913_preop/segmentation_sinus_r.nii.gz
# no separate z, order 3
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/321_8226809_160315_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/321_8226809_160315_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/376_4303442_170904_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/376_4303442_170904_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# no separate z, order 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/323_8261260_160602_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/323_8261260_160602_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/327_3398845_160725_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/327_3398845_160725_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/380_7728331_171122_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/380_7728331_171122_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/330_4306801_160808_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/330_4306801_160808_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/332_8305043_160804_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/332_8305043_160804_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/381_8562215_171121_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/381_8562215_171121_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/346_8401794_170216_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/346_8401794_170216_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/334_8305285_160823_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/334_8305285_160823_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/347_8386115_170117_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/347_8386115_170117_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/382_8525777_171114_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/382_8525777_171114_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/385_2249575_171206_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/385_2249575_171206_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/353_8416276_170222_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/353_8416276_170222_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/384_5478395_171114_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/384_5478395_171114_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/361_8444911_170405_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/361_8444911_170405_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/386_8575248_171219_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/386_8575248_171219_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/402_8624982_180316_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/402_8624982_180316_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/389_8566931_171205_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/389_8566931_171205_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/404_4113614_180228_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/404_4113614_180228_preop/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/416_5798318_180419_preop_ADK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/416_5798318_180419_preop_ADK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/391_8584746_180106_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/391_8584746_180106_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/417_8482608_180515_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/417_8482608_180515_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/405_8631223_180320_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/405_8631223_180320_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/395_8598198_180228_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/395_8598198_180228_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/420_7990844_180510_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/420_7990844_180510_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/406_8628923_180326_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/406_8628923_180326_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/396_8602575_180201_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/396_8602575_180201_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/430_8701549_180720_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/430_8701549_180720_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/408_8632378_180405_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/408_8632378_180405_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/397_8620227_180305_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/397_8620227_180305_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/410_8637071_180405_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/410_8637071_180405_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/431_8709312_180809_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/431_8709312_180809_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/412_5291274_180412_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/412_5291274_180412_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/398_8620702_180301_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/398_8620702_180301_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/432_8711880_180813_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/432_8711880_180813_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/413_8638636_180416_preop_ADK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/413_8638636_180416_preop_ADK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/441_5463336_181105_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/441_5463336_181105_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/433_8722184_180821_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/433_8722184_180821_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/444_8758096_181030_preop_dual/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/444_8758096_181030_preop_dual/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/434_8725519_180906_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/434_8725519_180906_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/477_8846897_190322_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/477_8846897_190322_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/451_8773160_181127_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/451_8773160_181127_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/500_10031429_190617_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/500_10031429_190617_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/457_8792862_181227_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/457_8792862_181227_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/480_7710708_190405_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/480_7710708_190405_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/502_10014545_190503_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/502_10014545_190503_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/483_7195195_190406_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/483_7195195_190406_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/460_8800307_190111_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/460_8800307_190111_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/503_10030059_190601_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/503_10030059_190601_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/486_8861002_190410_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/486_8861002_190410_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/461_3489041_190103_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/461_3489041_190103_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/504_3718217_190515_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/504_3718217_190515_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/489_10009092_190510_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/489_10009092_190510_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/468_8820018_190124_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/468_8820018_190124_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/507_10035193_190528_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/507_10035193_190528_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/491_10006242_190422_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/491_10006242_190422_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/509_10034811_190527_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/509_10034811_190527_preop/segmentation_sinus_r.nii.gz
# no separate z, order 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/469_8816368_190207_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/469_8816368_190207_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/493_10004624_190503_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/493_10004624_190503_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/517_10052386_190719_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/517_10052386_190719_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/498_10019164_190523_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/498_10019164_190523_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# no separate z, order 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/536_10080252_190904_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/536_10080252_190904_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/519_10047095_190705_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/519_10047095_190705_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/538_10070524_190810_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/538_10070524_190810_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/520_8843856_190327_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/520_8843856_190327_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/522_5446805_190719_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/522_5446805_190719_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/539_10093252_190927_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/539_10093252_190927_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/540_5063343_191004_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/540_5063343_191004_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/523_4176545_190719_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/523_4176545_190719_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/544_8279694_191008_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/544_8279694_191008_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/524_4040707_190803_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/524_4040707_190803_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/525_10053706_190715_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/525_10053706_190715_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/545_10110066_191027_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/545_10110066_191027_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/529_3732432_190819_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/529_3732432_190819_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/546_10111427_191028_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/546_10111427_191028_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/548_10104793_191017_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/548_10104793_191017_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/547_10109737_191024_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/547_10109737_191024_preop/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/510_4181446_190701_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/510_4181446_190701_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/557_10133737_191206_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/557_10133737_191206_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/513_10040117_190618_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/513_10040117_190618_preop/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/558_10097620_191216_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/558_10097620_191216_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/559_5889902_191207_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/559_5889902_191207_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/560_2648192_191212_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/560_2648192_191212_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/562_8217005_191202_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/562_8217005_191202_preop/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/565_8849689_191129_preop/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/565_8849689_191129_preop/segmentation_sinus_r.nii.gz

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1'
for f in subfolders(data_path, join=False):
    resample_tindex(f)
# Out:
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/001_2627046_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/001_2627046_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/001_2627046_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/001_2627046_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_220325_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_220325_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_220325_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/002_3685594_220325_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/003_2597321_211217_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/003_2597321_211217_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/003_2597321_211217_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/003_2597321_211217_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/004_10506248_211220_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/004_10506248_211220_CMP_preop_KO/segmentation_sinus_r.nii.gz
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/uk/lib/python3.7/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/004_10506248_211220_NP_preop_HK/segmentation_sinus.nii.gz'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-4b7facfc34c2> in <module>
#       1 data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1'
#       2 for f in subfolders(data_path, join=False):
# ----> 3     resample_tindex(f)
#
# <ipython-input-2-1e76d9f04b07> in resample_tindex(fold)
#      10         vol = a.get_fdata()
#      11
# ---> 12         b = nib.load(seg_path)
#      13         seg = b.get_fdata()
#      14
#
# ~/anaconda3/envs/uk/lib/python3.7/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      42         stat_result = os.stat(filename)
#      43     except OSError:
# ---> 44         raise FileNotFoundError("No such file or no access: '%s'" % filename)
#      45     if stat_result.st_size <= 0:
#      46         raise ImageFileError("Empty file: '%s'" % filename)
#
# FileNotFoundError: No such file or no access: '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_1/004_10506248_211220_NP_preop_HK/segmentation_sinus.nii.gz'

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2'
for f in subfolders(data_path, join=False):
    resample_tindex(f)
# Out:
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/001_2627046_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/001_2627046_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/001_2627046_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/001_2627046_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_220325_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_220325_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_220325_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/002_3685594_220325_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/003_2597321_211217_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/003_2597321_211217_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/003_2597321_211217_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/003_2597321_211217_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_211220_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_211220_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_211220_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_211220_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_220603_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_220603_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_220603_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_220603_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_221202_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_221202_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_221202_NP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/004_10506248_221202_NP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/005_5681816_211223_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/005_5681816_211223_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/005_5681816_211223_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/005_5681816_211223_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220103_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220103_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220103_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220103_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220607_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220607_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220607_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/006_10515548_220607_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/007_8572841_220127_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/007_8572841_220127_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/007_8572841_220127_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/007_8572841_220127_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/009_10537082_220215_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/009_10537082_220215_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/009_10537082_220215_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/009_10537082_220215_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/010_10537082_220311_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/010_10537082_220311_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/010_10554561_220311_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/010_10554561_220311_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/011_8317556_220509_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/011_8317556_220509_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/011_8317556_220509_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/011_8317556_220509_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/012_10652021_20220812_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/012_10652021_20220812_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/012_10652021_220812_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_2/012_10652021_220812_CMP_preop_KO/segmentation_sinus_r.nii.gz

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3'
for f in subfolders(data_path, join=False):
    resample_tindex(f)
# Out:
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/001_2627046_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/001_2627046_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/001_2627046_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/001_2627046_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_220325_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_220325_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_220325_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/002_3685594_220325_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/003_2597321_211217_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/003_2597321_211217_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/003_2597321_211217_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/003_2597321_211217_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_211220_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_211220_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_211220_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_211220_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_220603_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_220603_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_220603_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_220603_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_221202_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_221202_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_221202_NP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/004_10506248_221202_NP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/005_5681816_211223_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/005_5681816_211223_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/005_5681816_211223_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/005_5681816_211223_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220103_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220103_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220103_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220103_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220607_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220607_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220607_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/006_10515548_220607_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/007_8572841_220127_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/007_8572841_220127_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/007_8572841_220127_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/007_8572841_220127_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/009_10537082_220215_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/009_10537082_220215_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/009_10537082_220215_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/009_10537082_220215_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/010_10537082_220311_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/010_10537082_220311_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/010_10554561_220311_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/010_10554561_220311_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/011_8317556_220509_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/011_8317556_220509_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/011_8317556_220509_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/011_8317556_220509_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/012_10652021_20220812_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/012_10652021_20220812_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/012_10652021_220812_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_3/012_10652021_220812_CMP_preop_KO/segmentation_sinus_r.nii.gz

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4'
for f in subfolders(data_path, join=False):
    resample_tindex(f)
# Out:
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/001_2627046_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/001_2627046_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/001_2627046_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/001_2627046_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_220325_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_220325_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_220325_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/002_3685594_220325_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/003_2597321_211217_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/003_2597321_211217_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/003_2597321_211217_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/003_2597321_211217_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_211220_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_211220_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_211220_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_211220_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_220603_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_220603_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_220603_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_220603_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_221202_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_221202_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_221202_NP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/004_10506248_221202_NP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/005_5681816_211223_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/005_5681816_211223_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/005_5681816_211223_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/005_5681816_211223_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220103_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220103_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220103_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220103_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220607_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220607_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220607_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/006_10515548_220607_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/007_8572841_220127_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/007_8572841_220127_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/007_8572841_220127_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/007_8572841_220127_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/009_10537082_220215_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/009_10537082_220215_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/009_10537082_220215_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/009_10537082_220215_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/010_10537082_220311_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/010_10537082_220311_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/010_10554561_220311_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/010_10554561_220311_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/011_8317556_220509_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/011_8317556_220509_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/011_8317556_220509_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/011_8317556_220509_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/012_10652021_20220812_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/012_10652021_20220812_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/012_10652021_220812_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_4/012_10652021_220812_CMP_preop_KO/segmentation_sinus_r.nii.gz

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0'
folders = subfolders(data_path, join=False)
from multiprocessing import Pool
p = Pool(3)
p.map(resample_tindex, folders)
p.close()
p.join()
# Out:
# separate z, order in z is 0 order inplane is 3
# separate z, order in z isseparate z, order in z is  00  order inplane isorder inplane is  33
#
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/001_2627046_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/001_2627046_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/003_2597321_211217_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/003_2597321_211217_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/001_2627046_211022_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/001_2627046_211022_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_220325_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_220325_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/003_2597321_211217_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/003_2597321_211217_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_211022_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_211022_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_220325_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/002_3685594_220325_NP_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_211220_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_211220_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_221202_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_221202_CMP_KO/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_211220_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_211220_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/005_5681816_211223_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/005_5681816_211223_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_221202_NP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_221202_NP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_220603_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/004_10506248_220603_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220103_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220103_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is  0order inplane is 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220103_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220103_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220607_CMP_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220607_CMP_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/007_8572841_220127_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/007_8572841_220127_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/005_5681816_211223_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/005_5681816_211223_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/009_10537082_220215_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/009_10537082_220215_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/010_10537082_220311_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/010_10537082_220311_CMP_preop_KO/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/009_10537082_220215_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/009_10537082_220215_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/010_10554561_220311_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/010_10554561_220311_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220607_NP_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/006_10515548_220607_NP_HK/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/011_8317556_220509_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/011_8317556_220509_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/011_8317556_220509_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/011_8317556_220509_CMP_preop_KO/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/007_8572841_220127_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/007_8572841_220127_CMP_preop_KO/segmentation_sinus_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/012_10652021_20220812_NP_preop_HK/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/012_10652021_20220812_NP_preop_HK/segmentation_sinus_r.nii.gz
# separate z, order in z is 0 order inplane is 3
# separate z, order in z is 0 order inplane is 1
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/012_10652021_220812_CMP_preop_KO/imaging_r.nii.gz
# save complete:  /home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0/012_10652021_220812_CMP_preop_KO/segmentation_sinus_r.nii.gz
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5948c9475b70> in <module>
#       3 from multiprocessing import Pool
#       4 p = Pool(3)
# ----> 5 p.map(resample_tindex, folders)
#       6 p.close()
#       7 p.join()
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/envs/uk/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/envs/uk/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
