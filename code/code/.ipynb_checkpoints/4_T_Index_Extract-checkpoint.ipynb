# %%
from batchgenerators.utilities.file_and_folder_operations import *
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import center_of_mass, binary_dilation
from scipy.spatial import distance
from skimage.measure import label  
import pandas as pd
import os

# %%
def main_extract_save(folder):
    dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = index_extract(folder)
    if dst_sn_m is not None:
        result_array = np.array((int(folder.split('/')[-1].split('_')[0]), dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa))

        save_path = folder + '/result2.npy'
        np.save(save_path, result_array)
        print(save_path)

# %%
def index_extract(folder):
    seg_file = folder+'/segmentation_sinus_r.nii.gz'
    seg = nib.load(seg_file)
    seg_data = seg.get_fdata()

    sinus_data = np.zeros(seg_data.shape)
    sinus_data[seg_data==4]=1
    
    # parenchyma island extract
    kid_data = np.zeros(seg_data.shape)
    kid_data[seg_data==1]=1

    kid_split = label(kid_data)
    assert(len(np.unique(kid_split))==3)

    kid_data_1 = np.zeros(seg_data.shape)
    kid_data_1[kid_split==1]=1
    kid_data_2 = np.zeros(seg_data.shape)
    kid_data_2[kid_split==2]=1

    # sinus island extract
    sinus_split = label(sinus_data)
    assert(len(np.unique(sinus_split))==3)

    sinus_data_1 = np.zeros(sinus_data.shape)
    sinus_data_1[sinus_split==1]=1
    sinus_data_2 = np.zeros(sinus_data.shape)
    sinus_data_2[sinus_split==2]=1

    # mass extract
    mass_data = np.zeros(seg_data.shape)
    mass_data[seg_data==2]=1
    #assert(len(np.unique(mass_data))==2)
    if len(np.unique(mass_data))!=2:
        return None, None, None, None, None

    # distance
    kid_data_1_center = center_of_mass(kid_data_1)
    kid_data_2_center = center_of_mass(kid_data_2)
    sinus_data_1_center = center_of_mass(sinus_data_1)
    sinus_data_2_center = center_of_mass(sinus_data_2)
    mass_center = center_of_mass(mass_data)

    dst_kd1_m = distance.euclidean(kid_data_1_center, mass_center)
    dst_kd2_m = distance.euclidean(kid_data_2_center, mass_center)
    dst_sn1_m = distance.euclidean(sinus_data_1_center, mass_center)
    dst_sn2_m = distance.euclidean(sinus_data_2_center, mass_center)

    if dst_kd1_m < dst_kd2_m:
        main_kid_data = kid_data_1.copy()
    else:
        main_kid_data = kid_data_2.copy()

    if dst_sn1_m < dst_sn2_m:
        main_sinus_data = sinus_data_1.copy()
    else:
        main_sinus_data = sinus_data_2.copy()
        
    dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = distance_extract(main_sinus_data, main_kid_data, mass_data, seg.affine)
    
    return dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa

# %%
def distance_extract(main_sinus_data, main_kid_data, mass_data, affine):
    # 1. mass_center - sinus_center distance
    sinus_center = center_of_mass(main_sinus_data)
    mass_center = center_of_mass(mass_data)
    dst_sn_m = dist_3d(sinus_center, mass_center, affine)
    
    # 2. mass_parenchyma_surface - sinus_center distance (3D)
    mass_dil_data = binary_dilation(mass_data)
    x,y,z = np.where((mass_dil_data==1) & (main_kid_data==1))
    mp_ct=0
    dst_mp_sn=0
    if len(x)!=0:
        for a,b,c in zip(x,y,z):
            dst_mp_sn += 1/dist_3d(sinus_center, (a,b,c), affine)
            mp_ct+=1
            
    # 3. mass_sinus_surface - sinus_center distance (3D)
    x,y,z = np.where((mass_dil_data==1) & (main_sinus_data==1))
    msn_ct=0
    dst_msn_sn=0
    if len(x)!=0:
        for a,b,c in zip(x,y,z):
            dst_msn_sn += 1/dist_3d(sinus_center, (a,b,c), affine) 
            msn_ct+=1
            
    #print(q)
    sc=abs(affine[0][0])

    mp_csa=mp_ct*sc*sc*sc
    msn_csa=msn_ct*sc*sc*sc
            
    return dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa

# %%
def dist_3d(first, second, affine):
    # first,second : 3d point
    # affine : nib-> .affine
    dst = distance.euclidean(first, second)
    dst *= affine[0][0]
    return abs(dst)

# %%
#data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask'
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii'
folders = subfolders(data_path)

# %%
from multiprocessing import Pool
p = Pool(4)
p.map(main_extract_save, folders)
p.close()
p.join()
# Out:
# /home/ldh/1_Tindex/data/T_Index_nii/001/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/023/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/003/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/041/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/061/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/005/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/063/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/026/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/008/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/064/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/044/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/029/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/010/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/048/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/032/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/067/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/033/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/016/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/069/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/053/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/035/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/018/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/055/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/070/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/037/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/072/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/021/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/057/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/074/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/073/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/040/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/086/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/102/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/058/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/075/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/103/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/060/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/076/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/087/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/104/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/077/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/088/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/113/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/105/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/090/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/080/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/107/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/092/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/081/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/116/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/108/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/095/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/082/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/098/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/119/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/109/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/083/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/100/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/120/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/112/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/131/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/150/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/171/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/126/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/135/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/152/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/172/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/175/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/127/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/137/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/153/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/179/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/128/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/140/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/158/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/142/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/143/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/182/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/129/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/160/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/196/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/183/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/144/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/162/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/146/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/197/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/186/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/164/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/212/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/195/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/198/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/167/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/237/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/216/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/199/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/254/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/200/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/258/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/241/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/217/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/203/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/269/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/218/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/242/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/205/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/220/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/274/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/246/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/225/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/208/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/276/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/230/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/248/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/281/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/295/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/282/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/232/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/299/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/250/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/301/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/293/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/251/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/305/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/253/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii/308/result2.npy

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask'
#data_path =  '/home/ldh/1_Tindex/data/T_Index_nii'
folders = subfolders(data_path)

# %%
from multiprocessing import Pool
p = Pool(8)
p.map(main_extract_save, folders)
p.close()
p.join()
# Out:
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/313_7074817_151218_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/332_8305043_160804_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/346_8401794_170216_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/374_7505332_170913_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/317_7665620_160217_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/347_8386115_170117_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/334_8305285_160823_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/376_4303442_170904_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/336_3828394_160818_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/353_8416276_170222_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/361_8444911_170405_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/380_7728331_171122_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/321_8226809_160315_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/338_8328258_161004_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/364_8479256_170705_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/323_8261260_160602_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/327_3398845_160725_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/339_8333066_160924_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/381_8562215_171121_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/369_8495693_170724_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/341_5514749_161111_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/330_4306801_160808_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/385_2249575_171206_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/397_8620227_180305_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/382_8525777_171114_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/408_8632378_180405_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/410_8637071_180405_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/384_5478395_171114_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/386_8575248_171219_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/398_8620702_180301_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/412_5291274_180412_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/402_8624982_180316_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/389_8566931_171205_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/413_8638636_180416_preop_ADK/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/420_7990844_180510_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/404_4113614_180228_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/391_8584746_180106_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/430_8701549_180720_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/395_8598198_180228_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/416_5798318_180419_preop_ADK/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/405_8631223_180320_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/417_8482608_180515_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/431_8709312_180809_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/396_8602575_180201_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/406_8628923_180326_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/441_5463336_181105_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/432_8711880_180813_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/468_8820018_190124_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/489_10009092_190510_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/444_8758096_181030_preop_dual/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/433_8722184_180821_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/434_8725519_180906_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/469_8816368_190207_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/451_8773160_181127_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/491_10006242_190422_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/457_8792862_181227_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/493_10004624_190503_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/503_10030059_190601_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/477_8846897_190322_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/460_8800307_190111_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/498_10019164_190523_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/504_3718217_190515_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/480_7710708_190405_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/461_3489041_190103_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/500_10031429_190617_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/507_10035193_190528_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/483_7195195_190406_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/502_10014545_190503_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/517_10052386_190719_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/509_10034811_190527_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/486_8861002_190410_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/525_10053706_190715_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/529_3732432_190819_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/544_8279694_191008_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/519_10047095_190705_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/536_10080252_190904_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/545_10110066_191027_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/520_8843856_190327_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/510_4181446_190701_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/538_10070524_190810_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/522_5446805_190719_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/546_10111427_191028_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/513_10040117_190618_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/539_10093252_190927_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/523_4176545_190719_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/540_5063343_191004_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/547_10109737_191024_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/558_10097620_191216_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/548_10104793_191017_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/524_4040707_190803_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/559_5889902_191207_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/560_2648192_191212_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/557_10133737_191206_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/562_8217005_191202_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask/565_8849689_191129_preop/result2.npy

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
folders = subfolders(data_path)

# %%
from multiprocessing import Pool
p = Pool(8)
p.map(main_extract_save, folders)
p.close()
p.join()
# Out:
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/313_7074817_151218_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/361_8444911_170405_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/332_8305043_160804_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/323_8261260_160602_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/346_8401794_170216_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/327_3398845_160725_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/374_7505332_170913_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/338_8328258_161004_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/364_8479256_170705_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/381_8562215_171121_preop/result2.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-54e8347337ce> in <module>
#       1 from multiprocessing import Pool
#       2 p = Pool(8)
# ----> 3 p.map(main_extract_save, folders)
#       4 p.close()
#       5 p.join()
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# ~/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# ~/anaconda3/envs/uk/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/envs/uk/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-17:
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-126-32fbd28e51f4>", line 2, in main_extract_save
#     dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = index_extract(folder)
#   File "<ipython-input-127-82eb7c81ddd7>", line 39, in index_extract
#     kid_data_2_center = center_of_mass(kid_data_2)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 1386, in center_of_mass
#     for dir in range(input.ndim)]
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 1386, in <listcomp>
#     for dir in range(input.ndim)]
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 615, in sum
#     count, sum = _stats(input, labels, index)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 506, in _stats
#     return single_group(input)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 503, in single_group
#     return vals.size, vals.sum()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/numpy/core/_methods.py", line 47, in _sum
#     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# KeyboardInterrupt
# Process ForkPoolWorker-13:
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-126-32fbd28e51f4>", line 2, in main_extract_save
#     dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = index_extract(folder)
#   File "<ipython-input-127-82eb7c81ddd7>", line 59, in index_extract
#     dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = distance_extract(main_sinus_data, main_kid_data, mass_data, seg.affine)
#   File "<ipython-input-128-c5c0a5b26de8>", line 4, in distance_extract
#     mass_center = center_of_mass(mass_data)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 1386, in center_of_mass
#     for dir in range(input.ndim)]
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/scipy/ndimage/measurements.py", line 1386, in <listcomp>
#     for dir in range(input.ndim)]
# KeyboardInterrupt
# Process ForkPoolWorker-19:
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-126-32fbd28e51f4>", line 2, in main_extract_save
#     dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = index_extract(folder)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-127-82eb7c81ddd7>", line 14, in index_extract
#     assert(len(np.unique(kid_split))==3)
#   File "<__array_function__ internals>", line 6, in unique
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/numpy/lib/arraysetops.py", line 261, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/numpy/lib/arraysetops.py", line 322, in _unique1d
#     ar.sort()
# KeyboardInterrupt
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-126-32fbd28e51f4>", line 2, in main_extract_save
#     dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = index_extract(folder)
#   File "<ipython-input-127-82eb7c81ddd7>", line 23, in index_extract
#     assert(len(np.unique(sinus_split))==3)
#   File "<__array_function__ internals>", line 6, in unique
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/numpy/lib/arraysetops.py", line 261, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/site-packages/numpy/lib/arraysetops.py", line 322, in _unique1d
#     ar.sort()
# KeyboardInterrupt
# Process ForkPoolWorker-16:
# Traceback (most recent call last):
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/ldh/anaconda3/envs/uk/lib/python3.7/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-126-32fbd28e51f4>", line 2, in main_extract_save
#     dst_sn_m, dst_mp_sn, dst_msn_sn, mp_csa, msn_csa = index_extract(folder)
#   File "<ipython-input-127-82eb7c81ddd7>", line 11, in index_extract
#     kid_data[seg_data==1]=1
# KeyboardInterrupt

# %% [markdown]
# # Test

# %%
folder = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred/313_7074817_151218_preop'
seg_file = folder+'/segmentation_sinus_r.nii.gz'
seg = nib.load(seg_file)
seg_data = seg.get_fdata()

sinus_data = np.zeros(seg_data.shape)
sinus_data[seg_data==4]=1

# parenchyma island extract
kid_data = np.zeros(seg_data.shape)
kid_data[seg_data==1]=1

kid_split = label(kid_data)
assert(len(np.unique(kid_split))==3)

kid_data_1 = np.zeros(seg_data.shape)
kid_data_1[kid_split==1]=1
kid_data_2 = np.zeros(seg_data.shape)
kid_data_2[kid_split==2]=1

# sinus island extract
sinus_split = label(sinus_data)
assert(len(np.unique(sinus_split))==3)

sinus_data_1 = np.zeros(sinus_data.shape)
sinus_data_1[sinus_split==1]=1
sinus_data_2 = np.zeros(sinus_data.shape)
sinus_data_2[sinus_split==2]=1

# mass extract
mass_data = np.zeros(seg_data.shape)
mass_data[seg_data==2]=1

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_0'
folders=subfolders(data_path)

# %%
main_extract_save(folders[0])

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_final_test/T_Index_extract_pred_
preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/580_10140888_200204_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/583_10160375_200120_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/584_5718731_200320_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/590_5496283_200429_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/591_10207803_200514_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/592-10179272-200119-preop
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/593_6043739_200601_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred/594_10171022_200114_preop

# %%
data_path =  '/home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask'
folders = subfolders(data_path)
for f in folders:
    try:
        main_extract_save(f)
    except:
        print(f)
# Out:
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/458_8794304_181227_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/459_3034805_181224_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/462_8035121_190108_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/464_8279838_190122_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/481_8856525_190404_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/485_8855172_190409_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/542_10097654_190928_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/573_101585253_200108_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/574_10166362_200130_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/576_10148339_191211_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/580_10140888_200204_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/583_10160375_200120_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/584_5718731_200320_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/590_5496283_200429_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/591_10207803_200514_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/592-10179272-200119-preop
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/593_6043739_200601_preop/result2.npy
# /home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask/594_10171022_200114_preop/result2.npy

# %%
import pandas as pd
df = pd.read_excel('/home/ldh/1_Tindex/data/PNX7Y_MR_CT_labeling_20220629.xlsx', sheet_name='Master Sheet')

# %%
t_index = []
data_path = '/home/ldh/1_Tindex/data/T_Index_nii'
for nb in df['연번(No.)'].values:
    result_path=None
    for d in subfolders(data_path, join=False):
        if d.startswith(str(nb).zfill(3)):
            result_path = data_path+'/'+d+'/result2.npy'
    try:
        result_array = np.load(result_path)
        t_index.append(result_array)
    except:
        t_index.append([nb,None,None,None,None,None])

# %%
dict_value = {
    "No" : df['연번(No.)'].values,
    "Pt_number" : df['Pt_number'].values,
    "WIT" : df['WIT'].values,
    "EBL" : df['EBL'].values,
    "Total Op time" : df['Total Op time'].values,
    "Op_date" : df['Op_date'].values,
    "Discharge_date" : df['Discharge_date'].values,
    "Preop_cr" : df['Preop_cr'].values,
    "Postop_Cr_1D" : df['Postop_Cr_1D'].values,
    "PADUA_Score" : df['PADUA_Score'].values,
    "RENAL_Score" : df['RENAL_Score'].values,
    "x_C_index" : df['x_C_index'].values,
    "y_C_index" : df['y_C_index'].values,
    "m_sn" : np.array(t_index)[:,1],
    "mp_sn" : np.array(t_index)[:,2],
    "ms_sn" : np.array(t_index)[:,3],
    "mp_csa" : np.array(t_index)[:,4],
    "ms_csa" : np.array(t_index)[:,5],
    "m_sn_ai" : np.nan,
    "mp_sn_ai" : np.nan,
    "ms_sn_ai" : np.nan,
    "mp_csa_ai" : np.nan,
    "ms_csa_ai" : np.nan,
    
}

# %%
new_df = pd.DataFrame(dict_value)
new_df.to_csv('/home/ldh/1_Tindex/data/T_Index_Extract_train2.csv', index=False)

# %%
t_index = []
t_index_ai = []
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_mask'
data_ai_path = '/home/ldh/1_Tindex/data/T_Index_nii_test/T_Index_extract_pred'
for nb in df['연번(No.)'].values:
    result_path=None
    result_ai_path=None
    for d in subfolders(data_path, join=False):
        if d.startswith(str(nb).zfill(3)):
            result_path = data_path+'/'+d+'/result2.npy'
            result_ai_path = data_ai_path+'/'+d+'/result2.npy'
    try:
        result_array = np.load(result_path)
        t_index.append(result_array)
    except:
        t_index.append([nb,None,None,None,None,None])
        
    try:
        result_ai_array = np.load(result_ai_path)
        t_index_ai.append(result_ai_array)
    except:
        t_index_ai.append([nb,None,None,None,None,None])

# %%
dict_value = {
    "No" : df['연번(No.)'].values,
    "Pt_number" : df['Pt_number'].values,
    "WIT" : df['WIT'].values,
    "EBL" : df['EBL'].values,
    "Total Op time" : df['Total Op time'].values,
    "Op_date" : df['Op_date'].values,
    "Discharge_date" : df['Discharge_date'].values,
    "Preop_cr" : df['Preop_cr'].values,
    "Postop_Cr_1D" : df['Postop_Cr_1D'].values,
    "PADUA_Score" : df['PADUA_Score'].values,
    "RENAL_Score" : df['RENAL_Score'].values,
    "x_C_index" : df['x_C_index'].values,
    "y_C_index" : df['y_C_index'].values,
    "m_sn" : np.array(t_index)[:,1],
    "mp_sn" : np.array(t_index)[:,2],
    "ms_sn" : np.array(t_index)[:,3],
    "mp_csa" : np.array(t_index)[:,4],
    "ms_csa" : np.array(t_index)[:,5],
    "m_sn_ai" : np.array(t_index_ai)[:,1],
    "mp_sn_ai" : np.array(t_index_ai)[:,2],
    "ms_sn_ai" : np.array(t_index_ai)[:,3],
    "mp_csa_ai" : np.array(t_index_ai)[:,4],
    "ms_csa_ai" : np.array(t_index_ai)[:,5],
}

# %%
new_df = pd.DataFrame(dict_value)
new_df.to_csv('/home/ldh/1_Tindex/data/T_Index_Extract_test2.csv', index=False)

# %%
t_index = []
t_index_ai = []
data_path = '/home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_mask'
data_ai_path = '/home/ldh/1_Tindex/data/T_Index_nii_test_B/T_Index_extract_pred'
for nb in df['연번(No.)'].values:
    result_path=None
    result_ai_path=None
    for d in subfolders(data_path, join=False):
        if d.startswith(str(nb).zfill(3)):
            result_path = data_path+'/'+d+'/result2.npy'
            result_ai_path = data_ai_path+'/'+d+'/result2.npy'
    try:
        result_array = np.load(result_path)
        t_index.append(result_array)
    except:
        t_index.append([nb,None,None,None,None,None])
        
    try:
        result_ai_array = np.load(result_ai_path)
        t_index_ai.append(result_ai_array)
    except:
        t_index_ai.append([nb,None,None,None,None,None])

# %%
dict_value = {
    "No" : df['연번(No.)'].values,
    "Pt_number" : df['Pt_number'].values,
    "WIT" : df['WIT'].values,
    "EBL" : df['EBL'].values,
    "Total Op time" : df['Total Op time'].values,
    "Op_date" : df['Op_date'].values,
    "Discharge_date" : df['Discharge_date'].values,
    "Preop_cr" : df['Preop_cr'].values,
    "Postop_Cr_1D" : df['Postop_Cr_1D'].values,
    "PADUA_Score" : df['PADUA_Score'].values,
    "RENAL_Score" : df['RENAL_Score'].values,
    "x_C_index" : df['x_C_index'].values,
    "y_C_index" : df['y_C_index'].values,
    "m_sn" : np.array(t_index)[:,1],
    "mp_sn" : np.array(t_index)[:,2],
    "ms_sn" : np.array(t_index)[:,3],
    "mp_csa" : np.array(t_index)[:,4],
    "ms_csa" : np.array(t_index)[:,5],
    "m_sn_ai" : np.array(t_index_ai)[:,1],
    "mp_sn_ai" : np.array(t_index_ai)[:,2],
    "ms_sn_ai" : np.array(t_index_ai)[:,3],
    "mp_csa_ai" : np.array(t_index_ai)[:,4],
    "ms_csa_ai" : np.array(t_index_ai)[:,5],
}

# %%
new_df = pd.DataFrame(dict_value)
new_df.to_csv('/home/ldh/1_Tindex/data/T_Index_Extract_testB.csv', index=False)
