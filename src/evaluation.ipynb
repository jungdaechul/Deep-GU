# %%
cd '/home/ldh/nnunet_code'
# Out:
# /home/ldh/nnunet_code

# %%
from nnunet.evaluation.evaluator import evaluate_folder

# %%
gt_path='//home/ldh/1_Tindex/data/T_Index_nii_test/mask'
pred_path='//home/ldh/1_Tindex/data/T_Index_nii_test/prediction'

# %%
evaluate_folder(gt_path, pred_path, (1,2,3))
# Out:
# OrderedDict([('all',
#               [OrderedDict([('1',
#                              OrderedDict([('Accuracy', 0.9993475051153273),
#                                           ('Avg. Surface Distance',
#                                            0.20931080161299426),
#                                           ('Avg. Symmetric Surface Distance',
#                                            0.24405746884180585),
#                                           ('Dice', 0.9682390910296653),
#                                           ('False Discovery Rate',
#                                            0.03857871585730965),
#                                           ('False Negative Rate',
#                                            0.024845716117656513),
#                                           ('False Omission Rate',
#                                            0.00025605372025406034),
#                                           ('False Positive Rate',
# ...
